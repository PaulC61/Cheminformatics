# %%
import pandas as pd

df = pd.read_csv('../../rawDSSCDBdata.csv')
df
# Out:
#         VOC    JSC      FF   PCE  \
# 0     687.0  10.79  0.7000  5.19
# 1     790.0   6.90  0.4700  2.60
# 2     835.0   7.70  0.4900  3.10
# 3     800.0   6.40  0.4300  2.20
# 4     651.0  10.30  0.7500  5.00
# 5     693.0  10.00  0.7500  5.10
# 6     740.0   8.00  0.7700  4.80
# 7     678.0  13.20  0.6700  6.00
# 8     695.0  12.20  0.7400  6.20
# 9     800.0   9.00  0.7600  5.50
# 10    560.0   3.41  0.7300  1.39
# 11    660.0   7.72  0.7100  3.62
# 12    600.0   4.03  0.7300  1.77
# 13    690.0   5.79  0.7000  2.80
# 14    580.0   3.33  0.7300  1.41
# 15    660.0   5.63  0.7000  2.60
# 16    380.0   4.50  0.6300  1.10
# 17    340.0   2.70  0.6300  0.60
# 18    490.0   7.50  0.7000  2.60
# 19    480.0  12.80  0.6000  3.70
# 20    470.0  15.10  0.5000  3.50
# 21    550.0  15.20  0.6200  5.20
# 22    530.0  13.20  0.6700  4.70
# 23    500.0   9.40  0.6500  3.10
# 24    500.0  12.90  0.6400  4.10
# 25    510.0  11.10  0.6000  3.40
# 26    410.0   4.10  0.5600  0.90
# ...
