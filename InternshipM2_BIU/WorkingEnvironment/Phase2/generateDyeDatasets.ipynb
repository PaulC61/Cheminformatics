# %% [markdown]
# Using your own cleaning methods

# %%
import pandas as pd
import numpy as np

rawGlobalDyes = pd.read_csv('../../rawDSSCDBdata.csv')

rawGlobalDyes.head()
# Out:
#      VOC    JSC    FF   PCE  \
# 0  687.0  10.79  0.70  5.19
# 1  790.0   6.90  0.47  2.60
# 2  835.0   7.70  0.49  3.10
# 3  800.0   6.40  0.43  2.20
# 4  651.0  10.30  0.75  5.00
#
#                                          Electrolyte Active area Co-adsorbent  \
# 0  0.6 M 1-methyl-3-propylimidazolium iodide (PMI...           -            -
# 1  0.17 M Spiro-MeOTAD, 0.11 mM tert-butylpyridin...       0.158            -
# 2  0.17 M Spiro-MeOTAD, 0.11 mM tert-butylpyridin...       0.158            -
# 3  0.17 M Spiro-MeOTAD, 0.11 mM tert-butylpyridin...       0.158            -
# 4  1,3-dimethylimidazolium iodide, 1-ethyl-3methy...       0.158            -
#
#   Co-sensitizer                                   Semiconductor Dye loading  \
# 0             -                      TiO2 (20 nm particle size)           -
# 1             -  TiO2 film (8 uM thick + 5 uM scattering layer)           -
# 2             -  TiO2 film (8 uM thick + 5 uM scattering layer)           -
# 3             -  TiO2 film (8 uM thick + 5 uM scattering layer)           -
# 4             -  TiO2 film (8 uM thick + 5 uM scattering layer)           -
#
#    ... Article EID Article year  Article year.1 Article electronic id  \
# 0  ...         NaN   01/01/2012       Hong_2012                   NaN
# 1  ...         NaN   01/01/2010  Alibabaei_2010                   NaN
# 2  ...         NaN   01/01/2010  Alibabaei_2010                   NaN
# 3  ...         NaN   01/01/2010  Alibabaei_2010                   NaN
# 4  ...         NaN   01/01/2010  Alibabaei_2010                   NaN
#
#   Article keywords                                     Molecule SMILE  \
# 0              NaN  N#C/C(=C\c1ccc(cc1)N(c1ccccc1)CCCCCCN1c2ccccc2...
# 1              NaN  N#C/C(=C\c1ccc(s1)c1ccc(s1)c1ccc(cc1)N(c1ccc(c...
# 2              NaN  N#C/C(=C\c1ccc(s1)c1ccc(cc1)N(c1ccc(cc1)/C=C/c...
# 3              NaN  CCN(c1ccc2c(c1)oc(=O)c(c2)/C=C/c1ccc(cc1)N(c1c...
# 4              NaN  N#C/C(=C\c1ccc(s1)c1ccc(s1)c1ccc(cc1)N(c1ccc(c...
#
#           Molecule keywords Molecule spectrum absorption maxima  \
# 0             phenothiazine                               439.0
# 1  coumarin, triphenylamine                               465.0
# 2  coumarin, triphenylamine                               460.0
# 3  coumarin, triphenylamine                               454.0
# 4  coumarin, triphenylamine                               465.0
#
#   Molecule spectrum emission maxima Molecule spectrum solvent
# 0                             576.0         CH2Cl2/MeOH (1:1)
# 1                             640.0           dichloromethane
# 2                             590.0           dichloromethane
# 3                             525.0           dichloromethane
# 4                             640.0           dichloromethane
#
# [5 rows x 30 columns]

# %%
rawGlobalDyes['Molecule keywords'] = rawGlobalDyes['Molecule keywords'].str.lower()

rawGlobalDyes.groupby(['Molecule keywords']).count().sort_values('PCE', ascending=False).head(15)
# Out:
#                                 VOC   JSC    FF   PCE  Electrolyte  \
# Molecule keywords
# triphenylamine                 1471  1471  1471  1471         1471
# porphyrin                       512   512   512   512          512
# phenothiazine                   384   384   384   384          384
# indoline                        376   376   376   376          376
# n719, ruthenium                 331   331   331   331          331
# carbazole                       267   267   267   267          267
# coumarin                        137   137   137   137          137
# n3, ruthenium                    74    74    74    74           74
# z907, ruthenium                  55    55    55    55           55
# hemicyanine                      43    43    43    43           43
# diphenylamine                    41    41    41    41           41
# phenoxazine                      34    34    34    34           34
# squaraine                        33    33    33    33           33
# tetrahydroquinoline              33    33    33    33           33
# phenothiazine, triphenylamine    21    21    21    21           21
#
#                                Active area  Co-adsorbent  Co-sensitizer  \
# Molecule keywords
# triphenylamine                        1471          1451           1471
# porphyrin                              512           511            512
# phenothiazine                          384           384            384
# indoline                               376           376            376
# n719, ruthenium                        326           328            329
# carbazole                              267           267            267
# coumarin                               137           137            137
# n3, ruthenium                           74            74             74
# z907, ruthenium                         55            55             55
# hemicyanine                             43            43             43
# diphenylamine                           41            41             41
# phenoxazine                             34            34             34
# squaraine                               33            33             33
# tetrahydroquinoline                     33            33             33
# phenothiazine, triphenylamine           21            21             21
#
#                                Semiconductor  Dye loading  ...  \
# Molecule keywords                                          ...
# triphenylamine                          1471         1471  ...
# porphyrin                                512          512  ...
# phenothiazine                            384          384  ...
# indoline                                 376          376  ...
# n719, ruthenium                          331          331  ...
# carbazole                                267          267  ...
# coumarin                                 137          137  ...
# n3, ruthenium                             74           74  ...
# z907, ruthenium                           55           55  ...
# hemicyanine                               43           43  ...
# diphenylamine                             41           41  ...
# phenoxazine                               34           34  ...
# squaraine                                 33           33  ...
# tetrahydroquinoline                       33           33  ...
# phenothiazine, triphenylamine             21           21  ...
#
#                                Article issue nr  Article EID  Article year  \
# Molecule keywords
# triphenylamine                             1175            0          1471
# porphyrin                                   449            0           512
# phenothiazine                               271            0           384
# indoline                                    332            0           376
# n719, ruthenium                             248            0           331
# carbazole                                   198            0           267
# coumarin                                    113            0           137
# n3, ruthenium                                69            0            74
# z907, ruthenium                              48            0            55
# hemicyanine                                  43            0            43
# diphenylamine                                30            0            41
# phenoxazine                                  19            0            34
# squaraine                                    23            0            33
# tetrahydroquinoline                          28            0            33
# phenothiazine, triphenylamine                21            0            21
#
#                                Article year.1  Article electronic id  \
# Molecule keywords
# triphenylamine                           1471                      0
# porphyrin                                 512                      0
# phenothiazine                             384                      0
# indoline                                  376                      0
# n719, ruthenium                           331                      0
# carbazole                                 267                      0
# coumarin                                  137                      0
# n3, ruthenium                              74                      0
# z907, ruthenium                            55                      0
# hemicyanine                                43                      0
# diphenylamine                              41                      0
# phenoxazine                                34                      0
# squaraine                                  33                      0
# tetrahydroquinoline                        33                      0
# phenothiazine, triphenylamine              21                      0
#
#                                Article keywords  Molecule SMILE  \
# Molecule keywords
# triphenylamine                                0            1471
# porphyrin                                     0             512
# phenothiazine                                 0             384
# indoline                                      0             376
# n719, ruthenium                               0             331
# carbazole                                     0             267
# coumarin                                      0             137
# n3, ruthenium                                 0              74
# z907, ruthenium                               0              55
# hemicyanine                                   0              43
# diphenylamine                                 0              41
# phenoxazine                                   0              34
# squaraine                                     0              33
# tetrahydroquinoline                           0              33
# phenothiazine, triphenylamine                 0              21
#
#                                Molecule spectrum absorption maxima  \
# Molecule keywords
# triphenylamine                                                1399
# porphyrin                                                      433
# phenothiazine                                                  366
# indoline                                                       353
# n719, ruthenium                                                  0
# carbazole                                                      229
# coumarin                                                       137
# n3, ruthenium                                                    0
# z907, ruthenium                                                 55
# hemicyanine                                                     43
# diphenylamine                                                   41
# phenoxazine                                                     33
# squaraine                                                       21
# tetrahydroquinoline                                             33
# phenothiazine, triphenylamine                                   21
#
#                                Molecule spectrum emission maxima  \
# Molecule keywords
# triphenylamine                                               459
# porphyrin                                                    352
# phenothiazine                                                181
# indoline                                                     141
# n719, ruthenium                                                0
# carbazole                                                    115
# coumarin                                                      96
# n3, ruthenium                                                  0
# z907, ruthenium                                                0
# hemicyanine                                                    6
# diphenylamine                                                 23
# phenoxazine                                                   29
# squaraine                                                      7
# tetrahydroquinoline                                           33
# phenothiazine, triphenylamine                                 21
#
#                                Molecule spectrum solvent
# Molecule keywords
# triphenylamine                                      1471
# porphyrin                                            512
# phenothiazine                                        384
# indoline                                             376
# n719, ruthenium                                      331
# carbazole                                            267
# coumarin                                             137
# n3, ruthenium                                         74
# z907, ruthenium                                       55
# hemicyanine                                           43
# diphenylamine                                         41
# phenoxazine                                           34
# squaraine                                             33
# tetrahydroquinoline                                   33
# phenothiazine, triphenylamine                         21
#
# [15 rows x 29 columns]

# %%
rawGlobalDyes

# solar simulator settings

varSolSim = ["AM 1.5G 100 mW/cm2", 
             "AM 1.5",
             "AM 1.5 100 mW/cm2", 
             "AM 1.5 100mW/cm2", 
             "AM 1.5G 100mW/cm2",
             "AM 1.5G, 100 mW/cm2", 
             "AM 1.5G 100 mW/cm2", 
             "AM 1.5G, 100mW/cm2",
             "AM 1.5G", 
             "AM 1.5 100mW/cm2", 
             "AM 1.5G, 100 mw/cm2", 
             "AM 1.5 G",
             "AM1.5G, 100 mW/cm2", 
             "AM1.5 G 100 mW/cm2" 
             ,"AM1.5G"
            ]

for index in range(len(varSolSim)):
    rawGlobalDyes.loc[(rawGlobalDyes['Solar simulator']==varSolSim[index]), 'Solar simulator'] = "AM 1.5G 100mW/cm2"

dyesFilterSolarSim = rawGlobalDyes.loc[rawGlobalDyes['Solar simulator'].str.contains('100')]

dyesFilterSolarSim
# Out:
#         VOC    JSC    FF   PCE  \
# 0     687.0  10.79  0.70  5.19
# 1     790.0   6.90  0.47  2.60
# 2     835.0   7.70  0.49  3.10
# 3     800.0   6.40  0.43  2.20
# 4     651.0  10.30  0.75  5.00
# ...     ...    ...   ...   ...
# 4421  666.0  17.84  0.74  8.79
# 4422  651.0   9.93  0.70  4.52
# 4423  667.0  12.85  0.71  6.09
# 4424  659.0  12.46  0.69  5.65
# 4425  641.0  12.37  0.66  5.21
#
#                                             Electrolyte Active area  \
# 0     0.6 M 1-methyl-3-propylimidazolium iodide (PMI...           -
# 1     0.17 M Spiro-MeOTAD, 0.11 mM tert-butylpyridin...       0.158
# 2     0.17 M Spiro-MeOTAD, 0.11 mM tert-butylpyridin...       0.158
# 3     0.17 M Spiro-MeOTAD, 0.11 mM tert-butylpyridin...       0.158
# 4     1,3-dimethylimidazolium iodide, 1-ethyl-3methy...       0.158
# ...                                                 ...         ...
# 4421  0.6 M 1-methyl-3-propylimidazolium iodide (PMI...    0.12 cm2
# 4422  0.6 M 1-methyl-3-propylimidazolium iodide (PMI...    0.12 cm2
# 4423  0.6 M 1-methyl-3-propylimidazolium iodide (PMI...    0.12 cm2
# 4424  0.6 M 1-methyl-3-propylimidazolium iodide (PMI...    0.12 cm2
# 4425  0.6 M 1-methyl-3-propylimidazolium iodide (PMI...    0.12 cm2
#
#      Co-adsorbent Co-sensitizer  \
# 0               -             -
# 1               -             -
# 2               -             -
# 3               -             -
# 4               -             -
# ...           ...           ...
# 4421            -             -
# 4422            -             -
# 4423            -             -
# 4424            -             -
# 4425            -             -
#
#                                        Semiconductor   Dye loading  ...  \
# 0                         TiO2 (20 nm particle size)             -  ...
# 1     TiO2 film (8 uM thick + 5 uM scattering layer)             -  ...
# 2     TiO2 film (8 uM thick + 5 uM scattering layer)             -  ...
# 3     TiO2 film (8 uM thick + 5 uM scattering layer)             -  ...
# 4     TiO2 film (8 uM thick + 5 uM scattering layer)             -  ...
# ...                                              ...           ...  ...
# 4421                                 TiO2 film 14 um             -  ...
# 4422                                 TiO2 film 14 um  296 nmol/cm2  ...
# 4423                                 TiO2 film 14 um  224 nmol/cm2  ...
# 4424                                 TiO2 film 14 um  187 nmol/cm2  ...
# 4425                                 TiO2 film 14 um  150 nmol/cm2  ...
#
#      Article EID Article year  Article year.1 Article electronic id  \
# 0            NaN   01/01/2012       Hong_2012                   NaN
# 1            NaN   01/01/2010  Alibabaei_2010                   NaN
# 2            NaN   01/01/2010  Alibabaei_2010                   NaN
# 3            NaN   01/01/2010  Alibabaei_2010                   NaN
# 4            NaN   01/01/2010  Alibabaei_2010                   NaN
# ...          ...          ...             ...                   ...
# 4421         NaN   01/01/2018       Liao_2018                   NaN
# 4422         NaN   01/01/2018       Liao_2018                   NaN
# 4423         NaN   01/01/2018       Liao_2018                   NaN
# 4424         NaN   01/01/2018       Liao_2018                   NaN
# 4425         NaN   01/01/2018       Liao_2018                   NaN
#
#      Article keywords                                     Molecule SMILE  \
# 0                 NaN  N#C/C(=C\c1ccc(cc1)N(c1ccccc1)CCCCCCN1c2ccccc2...
# 1                 NaN  N#C/C(=C\c1ccc(s1)c1ccc(s1)c1ccc(cc1)N(c1ccc(c...
# 2                 NaN  N#C/C(=C\c1ccc(s1)c1ccc(cc1)N(c1ccc(cc1)/C=C/c...
# 3                 NaN  CCN(c1ccc2c(c1)oc(=O)c(c2)/C=C/c1ccc(cc1)N(c1c...
# 4                 NaN  N#C/C(=C\c1ccc(s1)c1ccc(s1)c1ccc(cc1)N(c1ccc(c...
# ...               ...                                                ...
# 4421              NaN  S=C=N[Ru]12(N=C=S)(N3CCC(CC3C3N2CCC(C3)C(=O)[O...
# 4422              NaN  C(#N)/C(/C(=O)O)=C\C=1SC(=CC1)C=1C=CC=2N(C3=CC...
# 4423              NaN  CSC1=CC=C(C=C1)C=1C=C2SC=3C=C(C=CC3N(C2=CC1)CC...
# 4424              NaN  COC1=CC=C(C=C1)C=1C=C2SC=3C=C(C=CC3N(C2=CC1)CC...
# 4425              NaN  CC1=CC=C(C=C1)C=1C=C2SC=3C=C(C=CC3N(C2=CC1)CCC...
#
#              Molecule keywords Molecule spectrum absorption maxima  \
# 0                phenothiazine                               439.0
# 1     coumarin, triphenylamine                               465.0
# 2     coumarin, triphenylamine                               460.0
# 3     coumarin, triphenylamine                               454.0
# 4     coumarin, triphenylamine                               465.0
# ...                        ...                                 ...
# 4421           n719, ruthenium                                 NaN
# 4422             phenothiazine                               473.0
# 4423             phenothiazine                               472.0
# 4424             phenothiazine                               470.0
# 4425             phenothiazine                               435.0
#
#      Molecule spectrum emission maxima Molecule spectrum solvent
# 0                                576.0         CH2Cl2/MeOH (1:1)
# 1                                640.0           dichloromethane
# 2                                590.0           dichloromethane
# 3                                525.0           dichloromethane
# 4                                640.0           dichloromethane
# ...                                ...                       ...
# 4421                               NaN                         -
# 4422                               NaN               CH2Cl2/EtOH
# 4423                               NaN               CH2Cl2/EtOH
# 4424                               NaN               CH2Cl2/EtOH
# 4425                               NaN               CH2Cl2/EtOH
#
# [4133 rows x 30 columns]

# %%
varElectrolyte = ["iod", "Iod","LiI", "I2", "AN-I", "Mosalyte", "HI-30"]

for index in range(len(varElectrolyte)):
    dyesFilterSolarSim.loc[(dyesFilterSolarSim['Electrolyte'].str.contains(varElectrolyte[index])), 'Electrolyte'] = "Iodide_Triiodide"

dyesFSolarSimNdElec = dyesFilterSolarSim.loc[dyesFilterSolarSim['Electrolyte']=="Iodide_Triiodide"]

dyesFSolarSimNdElec
# Out:
# C:\Users\clarkep\Anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#         VOC    JSC    FF   PCE       Electrolyte Active area Co-adsorbent  \
# 0     687.0  10.79  0.70  5.19  Iodide_Triiodide           -            -
# 4     651.0  10.30  0.75  5.00  Iodide_Triiodide       0.158            -
# 5     693.0  10.00  0.75  5.10  Iodide_Triiodide       0.158            -
# 6     740.0   8.00  0.77  4.80  Iodide_Triiodide       0.158            -
# 7     678.0  13.20  0.67  6.00  Iodide_Triiodide       0.158            -
# ...     ...    ...   ...   ...               ...         ...          ...
# 4421  666.0  17.84  0.74  8.79  Iodide_Triiodide    0.12 cm2            -
# 4422  651.0   9.93  0.70  4.52  Iodide_Triiodide    0.12 cm2            -
# 4423  667.0  12.85  0.71  6.09  Iodide_Triiodide    0.12 cm2            -
# 4424  659.0  12.46  0.69  5.65  Iodide_Triiodide    0.12 cm2            -
# 4425  641.0  12.37  0.66  5.21  Iodide_Triiodide    0.12 cm2            -
#
#      Co-sensitizer                                   Semiconductor  \
# 0                -                      TiO2 (20 nm particle size)
# 4                -  TiO2 film (8 uM thick + 5 uM scattering layer)
# 5                -  TiO2 film (8 uM thick + 5 uM scattering layer)
# 6                -  TiO2 film (8 uM thick + 5 uM scattering layer)
# 7                -  TiO2 film (8 uM thick + 5 uM scattering layer)
# ...            ...                                             ...
# 4421             -                                 TiO2 film 14 um
# 4422             -                                 TiO2 film 14 um
# 4423             -                                 TiO2 film 14 um
# 4424             -                                 TiO2 film 14 um
# 4425             -                                 TiO2 film 14 um
#
#        Dye loading  ... Article EID Article year  Article year.1  \
# 0                -  ...         NaN   01/01/2012       Hong_2012
# 4                -  ...         NaN   01/01/2010  Alibabaei_2010
# 5                -  ...         NaN   01/01/2010  Alibabaei_2010
# 6                -  ...         NaN   01/01/2010  Alibabaei_2010
# 7                -  ...         NaN   01/01/2010  Alibabaei_2010
# ...            ...  ...         ...          ...             ...
# 4421             -  ...         NaN   01/01/2018       Liao_2018
# 4422  296 nmol/cm2  ...         NaN   01/01/2018       Liao_2018
# 4423  224 nmol/cm2  ...         NaN   01/01/2018       Liao_2018
# 4424  187 nmol/cm2  ...         NaN   01/01/2018       Liao_2018
# 4425  150 nmol/cm2  ...         NaN   01/01/2018       Liao_2018
#
#      Article electronic id Article keywords  \
# 0                      NaN              NaN
# 4                      NaN              NaN
# 5                      NaN              NaN
# 6                      NaN              NaN
# 7                      NaN              NaN
# ...                    ...              ...
# 4421                   NaN              NaN
# 4422                   NaN              NaN
# 4423                   NaN              NaN
# 4424                   NaN              NaN
# 4425                   NaN              NaN
#
#                                          Molecule SMILE  \
# 0     N#C/C(=C\c1ccc(cc1)N(c1ccccc1)CCCCCCN1c2ccccc2...
# 4     N#C/C(=C\c1ccc(s1)c1ccc(s1)c1ccc(cc1)N(c1ccc(c...
# 5     N#C/C(=C\c1ccc(s1)c1ccc(cc1)N(c1ccc(cc1)/C=C/c...
# 6     CCN(c1ccc2c(c1)oc(=O)c(c2)/C=C/c1ccc(cc1)N(c1c...
# 7     N#C/C(=C\c1ccc(s1)c1ccc(s1)c1ccc(cc1)N(c1ccc(c...
# ...                                                 ...
# 4421  S=C=N[Ru]12(N=C=S)(N3CCC(CC3C3N2CCC(C3)C(=O)[O...
# 4422  C(#N)/C(/C(=O)O)=C\C=1SC(=CC1)C=1C=CC=2N(C3=CC...
# 4423  CSC1=CC=C(C=C1)C=1C=C2SC=3C=C(C=CC3N(C2=CC1)CC...
# 4424  COC1=CC=C(C=C1)C=1C=C2SC=3C=C(C=CC3N(C2=CC1)CC...
# 4425  CC1=CC=C(C=C1)C=1C=C2SC=3C=C(C=CC3N(C2=CC1)CCC...
#
#              Molecule keywords Molecule spectrum absorption maxima  \
# 0                phenothiazine                               439.0
# 4     coumarin, triphenylamine                               465.0
# 5     coumarin, triphenylamine                               460.0
# 6     coumarin, triphenylamine                               454.0
# 7     coumarin, triphenylamine                               465.0
# ...                        ...                                 ...
# 4421           n719, ruthenium                                 NaN
# 4422             phenothiazine                               473.0
# 4423             phenothiazine                               472.0
# 4424             phenothiazine                               470.0
# 4425             phenothiazine                               435.0
#
#      Molecule spectrum emission maxima Molecule spectrum solvent
# 0                                576.0         CH2Cl2/MeOH (1:1)
# 4                                640.0           dichloromethane
# 5                                590.0           dichloromethane
# 6                                525.0           dichloromethane
# 7                                640.0           dichloromethane
# ...                                ...                       ...
# 4421                               NaN                         -
# 4422                               NaN               CH2Cl2/EtOH
# 4423                               NaN               CH2Cl2/EtOH
# 4424                               NaN               CH2Cl2/EtOH
# 4425                               NaN               CH2Cl2/EtOH
#
# [3801 rows x 30 columns]

# %%
dyesFCoObjects = dyesFSolarSimNdElec.loc[(dyesFSolarSimNdElec['Co-adsorbent']=="-") & (dyesFSolarSimNdElec['Co-sensitizer']=="-")]

dyesFCoObjects
# Out:
#         VOC    JSC    FF   PCE       Electrolyte Active area Co-adsorbent  \
# 0     687.0  10.79  0.70  5.19  Iodide_Triiodide           -            -
# 4     651.0  10.30  0.75  5.00  Iodide_Triiodide       0.158            -
# 5     693.0  10.00  0.75  5.10  Iodide_Triiodide       0.158            -
# 6     740.0   8.00  0.77  4.80  Iodide_Triiodide       0.158            -
# 7     678.0  13.20  0.67  6.00  Iodide_Triiodide       0.158            -
# ...     ...    ...   ...   ...               ...         ...          ...
# 4421  666.0  17.84  0.74  8.79  Iodide_Triiodide    0.12 cm2            -
# 4422  651.0   9.93  0.70  4.52  Iodide_Triiodide    0.12 cm2            -
# 4423  667.0  12.85  0.71  6.09  Iodide_Triiodide    0.12 cm2            -
# 4424  659.0  12.46  0.69  5.65  Iodide_Triiodide    0.12 cm2            -
# 4425  641.0  12.37  0.66  5.21  Iodide_Triiodide    0.12 cm2            -
#
#      Co-sensitizer                                   Semiconductor  \
# 0                -                      TiO2 (20 nm particle size)
# 4                -  TiO2 film (8 uM thick + 5 uM scattering layer)
# 5                -  TiO2 film (8 uM thick + 5 uM scattering layer)
# 6                -  TiO2 film (8 uM thick + 5 uM scattering layer)
# 7                -  TiO2 film (8 uM thick + 5 uM scattering layer)
# ...            ...                                             ...
# 4421             -                                 TiO2 film 14 um
# 4422             -                                 TiO2 film 14 um
# 4423             -                                 TiO2 film 14 um
# 4424             -                                 TiO2 film 14 um
# 4425             -                                 TiO2 film 14 um
#
#        Dye loading  ... Article EID Article year  Article year.1  \
# 0                -  ...         NaN   01/01/2012       Hong_2012
# 4                -  ...         NaN   01/01/2010  Alibabaei_2010
# 5                -  ...         NaN   01/01/2010  Alibabaei_2010
# 6                -  ...         NaN   01/01/2010  Alibabaei_2010
# 7                -  ...         NaN   01/01/2010  Alibabaei_2010
# ...            ...  ...         ...          ...             ...
# 4421             -  ...         NaN   01/01/2018       Liao_2018
# 4422  296 nmol/cm2  ...         NaN   01/01/2018       Liao_2018
# 4423  224 nmol/cm2  ...         NaN   01/01/2018       Liao_2018
# 4424  187 nmol/cm2  ...         NaN   01/01/2018       Liao_2018
# 4425  150 nmol/cm2  ...         NaN   01/01/2018       Liao_2018
#
#      Article electronic id Article keywords  \
# 0                      NaN              NaN
# 4                      NaN              NaN
# 5                      NaN              NaN
# 6                      NaN              NaN
# 7                      NaN              NaN
# ...                    ...              ...
# 4421                   NaN              NaN
# 4422                   NaN              NaN
# 4423                   NaN              NaN
# 4424                   NaN              NaN
# 4425                   NaN              NaN
#
#                                          Molecule SMILE  \
# 0     N#C/C(=C\c1ccc(cc1)N(c1ccccc1)CCCCCCN1c2ccccc2...
# 4     N#C/C(=C\c1ccc(s1)c1ccc(s1)c1ccc(cc1)N(c1ccc(c...
# 5     N#C/C(=C\c1ccc(s1)c1ccc(cc1)N(c1ccc(cc1)/C=C/c...
# 6     CCN(c1ccc2c(c1)oc(=O)c(c2)/C=C/c1ccc(cc1)N(c1c...
# 7     N#C/C(=C\c1ccc(s1)c1ccc(s1)c1ccc(cc1)N(c1ccc(c...
# ...                                                 ...
# 4421  S=C=N[Ru]12(N=C=S)(N3CCC(CC3C3N2CCC(C3)C(=O)[O...
# 4422  C(#N)/C(/C(=O)O)=C\C=1SC(=CC1)C=1C=CC=2N(C3=CC...
# 4423  CSC1=CC=C(C=C1)C=1C=C2SC=3C=C(C=CC3N(C2=CC1)CC...
# 4424  COC1=CC=C(C=C1)C=1C=C2SC=3C=C(C=CC3N(C2=CC1)CC...
# 4425  CC1=CC=C(C=C1)C=1C=C2SC=3C=C(C=CC3N(C2=CC1)CCC...
#
#              Molecule keywords Molecule spectrum absorption maxima  \
# 0                phenothiazine                               439.0
# 4     coumarin, triphenylamine                               465.0
# 5     coumarin, triphenylamine                               460.0
# 6     coumarin, triphenylamine                               454.0
# 7     coumarin, triphenylamine                               465.0
# ...                        ...                                 ...
# 4421           n719, ruthenium                                 NaN
# 4422             phenothiazine                               473.0
# 4423             phenothiazine                               472.0
# 4424             phenothiazine                               470.0
# 4425             phenothiazine                               435.0
#
#      Molecule spectrum emission maxima Molecule spectrum solvent
# 0                                576.0         CH2Cl2/MeOH (1:1)
# 4                                640.0           dichloromethane
# 5                                590.0           dichloromethane
# 6                                525.0           dichloromethane
# 7                                640.0           dichloromethane
# ...                                ...                       ...
# 4421                               NaN                         -
# 4422                               NaN               CH2Cl2/EtOH
# 4423                               NaN               CH2Cl2/EtOH
# 4424                               NaN               CH2Cl2/EtOH
# 4425                               NaN               CH2Cl2/EtOH
#
# [2471 rows x 30 columns]

# %%
dyesFSemiConductor = dyesFCoObjects.loc[dyesFCoObjects['Semiconductor'].str.contains('TiO2')]

dyesFSemiConductor
# Out:
#         VOC    JSC    FF   PCE       Electrolyte Active area Co-adsorbent  \
# 0     687.0  10.79  0.70  5.19  Iodide_Triiodide           -            -
# 4     651.0  10.30  0.75  5.00  Iodide_Triiodide       0.158            -
# 5     693.0  10.00  0.75  5.10  Iodide_Triiodide       0.158            -
# 6     740.0   8.00  0.77  4.80  Iodide_Triiodide       0.158            -
# 7     678.0  13.20  0.67  6.00  Iodide_Triiodide       0.158            -
# ...     ...    ...   ...   ...               ...         ...          ...
# 4421  666.0  17.84  0.74  8.79  Iodide_Triiodide    0.12 cm2            -
# 4422  651.0   9.93  0.70  4.52  Iodide_Triiodide    0.12 cm2            -
# 4423  667.0  12.85  0.71  6.09  Iodide_Triiodide    0.12 cm2            -
# 4424  659.0  12.46  0.69  5.65  Iodide_Triiodide    0.12 cm2            -
# 4425  641.0  12.37  0.66  5.21  Iodide_Triiodide    0.12 cm2            -
#
#      Co-sensitizer                                   Semiconductor  \
# 0                -                      TiO2 (20 nm particle size)
# 4                -  TiO2 film (8 uM thick + 5 uM scattering layer)
# 5                -  TiO2 film (8 uM thick + 5 uM scattering layer)
# 6                -  TiO2 film (8 uM thick + 5 uM scattering layer)
# 7                -  TiO2 film (8 uM thick + 5 uM scattering layer)
# ...            ...                                             ...
# 4421             -                                 TiO2 film 14 um
# 4422             -                                 TiO2 film 14 um
# 4423             -                                 TiO2 film 14 um
# 4424             -                                 TiO2 film 14 um
# 4425             -                                 TiO2 film 14 um
#
#        Dye loading  ... Article EID Article year  Article year.1  \
# 0                -  ...         NaN   01/01/2012       Hong_2012
# 4                -  ...         NaN   01/01/2010  Alibabaei_2010
# 5                -  ...         NaN   01/01/2010  Alibabaei_2010
# 6                -  ...         NaN   01/01/2010  Alibabaei_2010
# 7                -  ...         NaN   01/01/2010  Alibabaei_2010
# ...            ...  ...         ...          ...             ...
# 4421             -  ...         NaN   01/01/2018       Liao_2018
# 4422  296 nmol/cm2  ...         NaN   01/01/2018       Liao_2018
# 4423  224 nmol/cm2  ...         NaN   01/01/2018       Liao_2018
# 4424  187 nmol/cm2  ...         NaN   01/01/2018       Liao_2018
# 4425  150 nmol/cm2  ...         NaN   01/01/2018       Liao_2018
#
#      Article electronic id Article keywords  \
# 0                      NaN              NaN
# 4                      NaN              NaN
# 5                      NaN              NaN
# 6                      NaN              NaN
# 7                      NaN              NaN
# ...                    ...              ...
# 4421                   NaN              NaN
# 4422                   NaN              NaN
# 4423                   NaN              NaN
# 4424                   NaN              NaN
# 4425                   NaN              NaN
#
#                                          Molecule SMILE  \
# 0     N#C/C(=C\c1ccc(cc1)N(c1ccccc1)CCCCCCN1c2ccccc2...
# 4     N#C/C(=C\c1ccc(s1)c1ccc(s1)c1ccc(cc1)N(c1ccc(c...
# 5     N#C/C(=C\c1ccc(s1)c1ccc(cc1)N(c1ccc(cc1)/C=C/c...
# 6     CCN(c1ccc2c(c1)oc(=O)c(c2)/C=C/c1ccc(cc1)N(c1c...
# 7     N#C/C(=C\c1ccc(s1)c1ccc(s1)c1ccc(cc1)N(c1ccc(c...
# ...                                                 ...
# 4421  S=C=N[Ru]12(N=C=S)(N3CCC(CC3C3N2CCC(C3)C(=O)[O...
# 4422  C(#N)/C(/C(=O)O)=C\C=1SC(=CC1)C=1C=CC=2N(C3=CC...
# 4423  CSC1=CC=C(C=C1)C=1C=C2SC=3C=C(C=CC3N(C2=CC1)CC...
# 4424  COC1=CC=C(C=C1)C=1C=C2SC=3C=C(C=CC3N(C2=CC1)CC...
# 4425  CC1=CC=C(C=C1)C=1C=C2SC=3C=C(C=CC3N(C2=CC1)CCC...
#
#              Molecule keywords Molecule spectrum absorption maxima  \
# 0                phenothiazine                               439.0
# 4     coumarin, triphenylamine                               465.0
# 5     coumarin, triphenylamine                               460.0
# 6     coumarin, triphenylamine                               454.0
# 7     coumarin, triphenylamine                               465.0
# ...                        ...                                 ...
# 4421           n719, ruthenium                                 NaN
# 4422             phenothiazine                               473.0
# 4423             phenothiazine                               472.0
# 4424             phenothiazine                               470.0
# 4425             phenothiazine                               435.0
#
#      Molecule spectrum emission maxima Molecule spectrum solvent
# 0                                576.0         CH2Cl2/MeOH (1:1)
# 4                                640.0           dichloromethane
# 5                                590.0           dichloromethane
# 6                                525.0           dichloromethane
# 7                                640.0           dichloromethane
# ...                                ...                       ...
# 4421                               NaN                         -
# 4422                               NaN               CH2Cl2/EtOH
# 4423                               NaN               CH2Cl2/EtOH
# 4424                               NaN               CH2Cl2/EtOH
# 4425                               NaN               CH2Cl2/EtOH
#
# [2426 rows x 30 columns]

# %%
dyesFSolarSim = dyesFSemiConductor.loc[dyesFSemiConductor['Solar simulator'].str.contains('100')]

dyesFSolarSim#.loc[dyesFSolarSim['Molecule SMILE'].str.contains('\.', regex=True)]
# Out:
#         VOC    JSC    FF   PCE       Electrolyte Active area Co-adsorbent  \
# 0     687.0  10.79  0.70  5.19  Iodide_Triiodide           -            -
# 4     651.0  10.30  0.75  5.00  Iodide_Triiodide       0.158            -
# 5     693.0  10.00  0.75  5.10  Iodide_Triiodide       0.158            -
# 6     740.0   8.00  0.77  4.80  Iodide_Triiodide       0.158            -
# 7     678.0  13.20  0.67  6.00  Iodide_Triiodide       0.158            -
# ...     ...    ...   ...   ...               ...         ...          ...
# 4421  666.0  17.84  0.74  8.79  Iodide_Triiodide    0.12 cm2            -
# 4422  651.0   9.93  0.70  4.52  Iodide_Triiodide    0.12 cm2            -
# 4423  667.0  12.85  0.71  6.09  Iodide_Triiodide    0.12 cm2            -
# 4424  659.0  12.46  0.69  5.65  Iodide_Triiodide    0.12 cm2            -
# 4425  641.0  12.37  0.66  5.21  Iodide_Triiodide    0.12 cm2            -
#
#      Co-sensitizer                                   Semiconductor  \
# 0                -                      TiO2 (20 nm particle size)
# 4                -  TiO2 film (8 uM thick + 5 uM scattering layer)
# 5                -  TiO2 film (8 uM thick + 5 uM scattering layer)
# 6                -  TiO2 film (8 uM thick + 5 uM scattering layer)
# 7                -  TiO2 film (8 uM thick + 5 uM scattering layer)
# ...            ...                                             ...
# 4421             -                                 TiO2 film 14 um
# 4422             -                                 TiO2 film 14 um
# 4423             -                                 TiO2 film 14 um
# 4424             -                                 TiO2 film 14 um
# 4425             -                                 TiO2 film 14 um
#
#        Dye loading  ... Article EID Article year  Article year.1  \
# 0                -  ...         NaN   01/01/2012       Hong_2012
# 4                -  ...         NaN   01/01/2010  Alibabaei_2010
# 5                -  ...         NaN   01/01/2010  Alibabaei_2010
# 6                -  ...         NaN   01/01/2010  Alibabaei_2010
# 7                -  ...         NaN   01/01/2010  Alibabaei_2010
# ...            ...  ...         ...          ...             ...
# 4421             -  ...         NaN   01/01/2018       Liao_2018
# 4422  296 nmol/cm2  ...         NaN   01/01/2018       Liao_2018
# 4423  224 nmol/cm2  ...         NaN   01/01/2018       Liao_2018
# 4424  187 nmol/cm2  ...         NaN   01/01/2018       Liao_2018
# 4425  150 nmol/cm2  ...         NaN   01/01/2018       Liao_2018
#
#      Article electronic id Article keywords  \
# 0                      NaN              NaN
# 4                      NaN              NaN
# 5                      NaN              NaN
# 6                      NaN              NaN
# 7                      NaN              NaN
# ...                    ...              ...
# 4421                   NaN              NaN
# 4422                   NaN              NaN
# 4423                   NaN              NaN
# 4424                   NaN              NaN
# 4425                   NaN              NaN
#
#                                          Molecule SMILE  \
# 0     N#C/C(=C\c1ccc(cc1)N(c1ccccc1)CCCCCCN1c2ccccc2...
# 4     N#C/C(=C\c1ccc(s1)c1ccc(s1)c1ccc(cc1)N(c1ccc(c...
# 5     N#C/C(=C\c1ccc(s1)c1ccc(cc1)N(c1ccc(cc1)/C=C/c...
# 6     CCN(c1ccc2c(c1)oc(=O)c(c2)/C=C/c1ccc(cc1)N(c1c...
# 7     N#C/C(=C\c1ccc(s1)c1ccc(s1)c1ccc(cc1)N(c1ccc(c...
# ...                                                 ...
# 4421  S=C=N[Ru]12(N=C=S)(N3CCC(CC3C3N2CCC(C3)C(=O)[O...
# 4422  C(#N)/C(/C(=O)O)=C\C=1SC(=CC1)C=1C=CC=2N(C3=CC...
# 4423  CSC1=CC=C(C=C1)C=1C=C2SC=3C=C(C=CC3N(C2=CC1)CC...
# 4424  COC1=CC=C(C=C1)C=1C=C2SC=3C=C(C=CC3N(C2=CC1)CC...
# 4425  CC1=CC=C(C=C1)C=1C=C2SC=3C=C(C=CC3N(C2=CC1)CCC...
#
#              Molecule keywords Molecule spectrum absorption maxima  \
# 0                phenothiazine                               439.0
# 4     coumarin, triphenylamine                               465.0
# 5     coumarin, triphenylamine                               460.0
# 6     coumarin, triphenylamine                               454.0
# 7     coumarin, triphenylamine                               465.0
# ...                        ...                                 ...
# 4421           n719, ruthenium                                 NaN
# 4422             phenothiazine                               473.0
# 4423             phenothiazine                               472.0
# 4424             phenothiazine                               470.0
# 4425             phenothiazine                               435.0
#
#      Molecule spectrum emission maxima Molecule spectrum solvent
# 0                                576.0         CH2Cl2/MeOH (1:1)
# 4                                640.0           dichloromethane
# 5                                590.0           dichloromethane
# 6                                525.0           dichloromethane
# 7                                640.0           dichloromethane
# ...                                ...                       ...
# 4421                               NaN                         -
# 4422                               NaN               CH2Cl2/EtOH
# 4423                               NaN               CH2Cl2/EtOH
# 4424                               NaN               CH2Cl2/EtOH
# 4425                               NaN               CH2Cl2/EtOH
#
# [2426 rows x 30 columns]

# %%
dyesFMixtures = dyesFSolarSim.loc[(~dyesFSolarSim['Molecule SMILE'].str.contains('\.', regex=True))]

dyesFMixtures
# Out:
#         VOC    JSC    FF   PCE       Electrolyte Active area Co-adsorbent  \
# 0     687.0  10.79  0.70  5.19  Iodide_Triiodide           -            -
# 4     651.0  10.30  0.75  5.00  Iodide_Triiodide       0.158            -
# 5     693.0  10.00  0.75  5.10  Iodide_Triiodide       0.158            -
# 6     740.0   8.00  0.77  4.80  Iodide_Triiodide       0.158            -
# 7     678.0  13.20  0.67  6.00  Iodide_Triiodide       0.158            -
# ...     ...    ...   ...   ...               ...         ...          ...
# 4419  740.0  14.56  0.68  7.39  Iodide_Triiodide           -            -
# 4422  651.0   9.93  0.70  4.52  Iodide_Triiodide    0.12 cm2            -
# 4423  667.0  12.85  0.71  6.09  Iodide_Triiodide    0.12 cm2            -
# 4424  659.0  12.46  0.69  5.65  Iodide_Triiodide    0.12 cm2            -
# 4425  641.0  12.37  0.66  5.21  Iodide_Triiodide    0.12 cm2            -
#
#      Co-sensitizer                                   Semiconductor  \
# 0                -                      TiO2 (20 nm particle size)
# 4                -  TiO2 film (8 uM thick + 5 uM scattering layer)
# 5                -  TiO2 film (8 uM thick + 5 uM scattering layer)
# 6                -  TiO2 film (8 uM thick + 5 uM scattering layer)
# 7                -  TiO2 film (8 uM thick + 5 uM scattering layer)
# ...            ...                                             ...
# 4419             -                                       TiO2 film
# 4422             -                                 TiO2 film 14 um
# 4423             -                                 TiO2 film 14 um
# 4424             -                                 TiO2 film 14 um
# 4425             -                                 TiO2 film 14 um
#
#        Dye loading  ... Article EID Article year        Article year.1  \
# 0                -  ...         NaN   01/01/2012             Hong_2012
# 4                -  ...         NaN   01/01/2010        Alibabaei_2010
# 5                -  ...         NaN   01/01/2010        Alibabaei_2010
# 6                -  ...         NaN   01/01/2010        Alibabaei_2010
# 7                -  ...         NaN   01/01/2010        Alibabaei_2010
# ...            ...  ...         ...          ...                   ...
# 4419             -  ...         NaN   01/01/2018  Ruangsupapichat_2018
# 4422  296 nmol/cm2  ...         NaN   01/01/2018             Liao_2018
# 4423  224 nmol/cm2  ...         NaN   01/01/2018             Liao_2018
# 4424  187 nmol/cm2  ...         NaN   01/01/2018             Liao_2018
# 4425  150 nmol/cm2  ...         NaN   01/01/2018             Liao_2018
#
#      Article electronic id Article keywords  \
# 0                      NaN              NaN
# 4                      NaN              NaN
# 5                      NaN              NaN
# 6                      NaN              NaN
# 7                      NaN              NaN
# ...                    ...              ...
# 4419                   NaN              NaN
# 4422                   NaN              NaN
# 4423                   NaN              NaN
# 4424                   NaN              NaN
# 4425                   NaN              NaN
#
#                                          Molecule SMILE  \
# 0     N#C/C(=C\c1ccc(cc1)N(c1ccccc1)CCCCCCN1c2ccccc2...
# 4     N#C/C(=C\c1ccc(s1)c1ccc(s1)c1ccc(cc1)N(c1ccc(c...
# 5     N#C/C(=C\c1ccc(s1)c1ccc(cc1)N(c1ccc(cc1)/C=C/c...
# 6     CCN(c1ccc2c(c1)oc(=O)c(c2)/C=C/c1ccc(cc1)N(c1c...
# 7     N#C/C(=C\c1ccc(s1)c1ccc(s1)c1ccc(cc1)N(c1ccc(c...
# ...                                                 ...
# 4419  C(CCCCC)N1C=2C=CC(=CC2C=2N(C=3C=CC(=CC3C21)/C=...
# 4422  C(#N)/C(/C(=O)O)=C\C=1SC(=CC1)C=1C=CC=2N(C3=CC...
# 4423  CSC1=CC=C(C=C1)C=1C=C2SC=3C=C(C=CC3N(C2=CC1)CC...
# 4424  COC1=CC=C(C=C1)C=1C=C2SC=3C=C(C=CC3N(C2=CC1)CC...
# 4425  CC1=CC=C(C=C1)C=1C=C2SC=3C=C(C=CC3N(C2=CC1)CCC...
#
#              Molecule keywords Molecule spectrum absorption maxima  \
# 0                phenothiazine                               439.0
# 4     coumarin, triphenylamine                               465.0
# 5     coumarin, triphenylamine                               460.0
# 6     coumarin, triphenylamine                               454.0
# 7     coumarin, triphenylamine                               465.0
# ...                        ...                                 ...
# 4419                  indoline                               411.0
# 4422             phenothiazine                               473.0
# 4423             phenothiazine                               472.0
# 4424             phenothiazine                               470.0
# 4425             phenothiazine                               435.0
#
#      Molecule spectrum emission maxima Molecule spectrum solvent
# 0                                576.0         CH2Cl2/MeOH (1:1)
# 4                                640.0           dichloromethane
# 5                                590.0           dichloromethane
# 6                                525.0           dichloromethane
# 7                                640.0           dichloromethane
# ...                                ...                       ...
# 4419                               NaN                  methanol
# 4422                               NaN               CH2Cl2/EtOH
# 4423                               NaN               CH2Cl2/EtOH
# 4424                               NaN               CH2Cl2/EtOH
# 4425                               NaN               CH2Cl2/EtOH
#
# [2144 rows x 30 columns]

# %%
dyesDropDuplicatesMixtures = dyesFSolarSim.sort_values('PCE', ascending=False).drop_duplicates('Molecule SMILE').sort_index()

dyesDropDuplicatesSingles = dyesFMixtures.sort_values('PCE', ascending=False).drop_duplicates('Molecule SMILE').sort_index()

# %%
metalsMixes = dyesDropDuplicatesMixtures

metalsMixes.shape
# Out:
# (1678, 30)

# %%
metalsNoMixes = dyesDropDuplicatesSingles

metalsNoMixes.shape
# Out:
# (1647, 30)

# %%
noMetalsMixes = metalsMixes.loc[(~metalsMixes['Molecule keywords'].str.contains('ruthenium'))
                                & (~metalsMixes['Molecule SMILE'].str.contains('Zn'))
                                   & (~metalsMixes['Molecule SMILE'].str.contains("se"))]

noMetalsMixes.shape #1678 -> 1464
# Out:
# (1464, 30)

# %%
noMetalsNoMixes = metalsNoMixes.loc[(~metalsNoMixes['Molecule SMILE'].str.contains('Ru'))
                                & (~metalsNoMixes['Molecule SMILE'].str.contains('Zn'))
                                   & (~metalsNoMixes['Molecule SMILE'].str.contains("se"))]

noMetalsNoMixes.shape #1647 -> 1436
# Out:
# (1436, 31)

# %%
noMetalsNoMixes.groupby(['Molecule keywords']).count().sort_values('PCE', ascending=False)
# Out:
#                                     VOC  JSC   FF  PCE  Electrolyte  \
# Molecule keywords
# triphenylamine                      551  551  551  551          551
# phenothiazine                       241  241  241  241          241
# carbazole                           139  139  139  139          139
# indoline                            111  111  111  111          111
# coumarin                             47   47   47   47           47
# ...                                 ...  ...  ...  ...          ...
# methoxyphenyl                         1    1    1    1            1
# phenanthrenequinone, phenothiazine    1    1    1    1            1
# phenothiazine, indole                 1    1    1    1            1
# phenoxazine,bodipy                    1    1    1    1            1
# truxene,triphenylamine                1    1    1    1            1
#
#                                     Active area  Co-adsorbent  Co-sensitizer  \
# Molecule keywords
# triphenylamine                              551           551            551
# phenothiazine                               241           241            241
# carbazole                                   139           139            139
# indoline                                    111           111            111
# coumarin                                     47            47             47
# ...                                         ...           ...            ...
# methoxyphenyl                                 1             1              1
# phenanthrenequinone, phenothiazine            1             1              1
# phenothiazine, indole                         1             1              1
# phenoxazine,bodipy                            1             1              1
# truxene,triphenylamine                        1             1              1
#
#                                     Semiconductor  Dye loading  ...  \
# Molecule keywords                                               ...
# triphenylamine                                551          551  ...
# phenothiazine                                 241          241  ...
# carbazole                                     139          139  ...
# indoline                                      111          111  ...
# coumarin                                       47           47  ...
# ...                                           ...          ...  ...
# methoxyphenyl                                   1            1  ...
# phenanthrenequinone, phenothiazine              1            1  ...
# phenothiazine, indole                           1            1  ...
# phenoxazine,bodipy                              1            1  ...
# truxene,triphenylamine                          1            1  ...
#
#                                     Article EID  Article year  Article year.1  \
# Molecule keywords
# triphenylamine                                0           551             551
# phenothiazine                                 0           241             241
# carbazole                                     0           139             139
# indoline                                      0           111             111
# coumarin                                      0            47              47
# ...                                         ...           ...             ...
# methoxyphenyl                                 0             1               1
# phenanthrenequinone, phenothiazine            0             1               1
# phenothiazine, indole                         0             1               1
# phenoxazine,bodipy                            0             1               1
# truxene,triphenylamine                        0             1               1
#
#                                     Article electronic id  Article keywords  \
# Molecule keywords
# triphenylamine                                          0                 0
# phenothiazine                                           0                 0
# carbazole                                               0                 0
# indoline                                                0                 0
# coumarin                                                0                 0
# ...                                                   ...               ...
# methoxyphenyl                                           0                 0
# phenanthrenequinone, phenothiazine                      0                 0
# phenothiazine, indole                                   0                 0
# phenoxazine,bodipy                                      0                 0
# truxene,triphenylamine                                  0                 0
#
#                                     Molecule SMILE  \
# Molecule keywords
# triphenylamine                                 551
# phenothiazine                                  241
# carbazole                                      139
# indoline                                       111
# coumarin                                        47
# ...                                            ...
# methoxyphenyl                                    1
# phenanthrenequinone, phenothiazine               1
# phenothiazine, indole                            1
# phenoxazine,bodipy                               1
# truxene,triphenylamine                           1
#
#                                     Molecule spectrum absorption maxima  \
# Molecule keywords
# triphenylamine                                                      520
# phenothiazine                                                       235
# carbazole                                                           134
# indoline                                                            108
# coumarin                                                             47
# ...                                                                 ...
# methoxyphenyl                                                         0
# phenanthrenequinone, phenothiazine                                    1
# phenothiazine, indole                                                 1
# phenoxazine,bodipy                                                    1
# truxene,triphenylamine                                                1
#
#                                     Molecule spectrum emission maxima  \
# Molecule keywords
# triphenylamine                                                    188
# phenothiazine                                                      96
# carbazole                                                          67
# indoline                                                           25
# coumarin                                                           37
# ...                                                               ...
# methoxyphenyl                                                       0
# phenanthrenequinone, phenothiazine                                  0
# phenothiazine, indole                                               0
# phenoxazine,bodipy                                                  0
# truxene,triphenylamine                                              1
#
#                                     Molecule spectrum solvent  Dragon Name
# Molecule keywords
# triphenylamine                                            551          551
# phenothiazine                                             241          241
# carbazole                                                 139          139
# indoline                                                  111          111
# coumarin                                                   47           47
# ...                                                       ...          ...
# methoxyphenyl                                               1            1
# phenanthrenequinone, phenothiazine                          1            1
# phenothiazine, indole                                       1            1
# phenoxazine,bodipy                                          1            1
# truxene,triphenylamine                                      1            1
#
# [97 rows x 30 columns]

# %%
noMetalsMixes.columns
# Out:
# Index(['VOC', 'JSC', 'FF', 'PCE', 'Electrolyte', 'Active area', 'Co-adsorbent',
#        'Co-sensitizer', 'Semiconductor', 'Dye loading', 'Exposure time',
#        'Solar simulator', 'Performance comment', 'Article author',
#        'Article title', 'Article journal', 'Article volume', 'Article DOI',
#        'Article pages', 'Article issue nr', 'Article EID', 'Article year',
#        'Article year.1', 'Article electronic id', 'Article keywords',
#        'Molecule SMILE', 'Molecule keywords',
#        'Molecule spectrum absorption maxima',
#        'Molecule spectrum emission maxima', 'Molecule spectrum solvent'],
#       dtype='object')

# %%
metalsMixes['Dragon Name'] = metalsMixes['Molecule keywords'] + ' ' + metalsMixes['PCE'].astype(str)
noMetalsMixes['Dragon Name'] = noMetalsMixes['Molecule keywords'] + ' ' + noMetalsMixes['PCE'].astype(str)
metalsNoMixes['Dragon Name'] = metalsNoMixes['Molecule keywords'] + ' ' + metalsNoMixes['PCE'].astype(str)
noMetalsNoMixes['Dragon Name'] = noMetalsNoMixes['Molecule keywords'] + ' ' + noMetalsNoMixes['PCE'].astype(str)
# Out:
# C:\Users\clarkep\AppData\Local\Temp/ipykernel_42160/3560792507.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   noMetalsMixes['Dragon Name'] = noMetalsMixes['Molecule keywords'] + ' ' + noMetalsMixes['PCE'].astype(str)
# C:\Users\clarkep\AppData\Local\Temp/ipykernel_42160/3560792507.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   noMetalsNoMixes['Dragon Name'] = noMetalsNoMixes['Molecule keywords'] + ' ' + noMetalsNoMixes['PCE'].astype(str)

# %%
metalsMixes.to_csv('metalsMixes.csv')
noMetalsMixes.to_csv('noMetalsMixes.csv')
metalsNoMixes.to_csv('metalsNoMixes.csv')
noMetalsNoMixes.to_csv('noMetalsNoMixes.csv')

# %%
metalsMixesSMI=pd.concat([metalsMixes['Dragon Name'], metalsMixes['Molecule SMILE']], axis=1)
noMetalsMixesSMI=pd.concat([noMetalsMixes['Dragon Name'], noMetalsMixes['Molecule SMILE']], axis=1)
metalsNoMixesSMI=pd.concat([metalsNoMixes['Dragon Name'], metalsNoMixes['Molecule SMILE']], axis=1)
noMetalsNoMixesSMI=pd.concat([noMetalsNoMixes['Dragon Name'], noMetalsNoMixes['Molecule SMILE']], axis=1)

# %%
metalsMixesSMI.to_csv('metalsMixes.smi', sep='\t', index=False, header=False)
noMetalsMixesSMI.to_csv('noMetalsMixes.smi', sep='\t', index=False, header=False)
metalsNoMixesSMI.to_csv('metalsNoMixes.smi', sep='\t', index=False, header=False)
noMetalsNoMixesSMI.to_csv('noMetalsNoMixes.smi', sep='\t', index=False, header=False)
