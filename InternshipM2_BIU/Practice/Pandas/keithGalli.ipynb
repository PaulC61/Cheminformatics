# %%
import pandas as pd

df = pd.read_csv('rawDSSCDBdata.csv')

# print(df.head(3))

df.describe()
df.sort_values(['PCE','FF'], ascending=[1,0])
# Out:
#          VOC     JSC      FF      PCE  \
# 3750   391.0   0.013  0.2738   0.0013
# 894    120.0   0.120  0.4200   0.0058
# 141    105.0   0.260  0.3700   0.0100
# 131    110.0   0.560  0.3100   0.0194
# 3224   190.0   0.240  0.5100   0.0200
# 3304   390.0   0.120  0.3800   0.0200
# 1847   330.0   0.150  0.3400   0.0200
# 963    380.0   0.150  0.5100   0.0300
# 962    370.0   0.140  0.5000   0.0300
# 3303   312.0   0.280  0.3400   0.0300
# 2556    97.0   1.040  0.3700   0.0370
# 1887   105.0   1.000  0.3500   0.0380
# 769    110.0   1.160  0.3100   0.0387
# 965    390.0   0.180  0.5300   0.0400
# 808    350.0   0.200  0.4850   0.0400
# 3223   200.0   0.540  0.3600   0.0400
# 3260   250.0   0.620  0.2500   0.0400
# 2927   300.0   0.280  0.5300   0.0460
# 2555    94.0   1.430  0.3700   0.0500
# 2670    95.0   1.480  0.3600   0.0500
# 2673    95.0   1.580  0.3500   0.0500
# 2579   113.0   1.380  0.3400   0.0530
# 768    130.0   1.350  0.3100   0.0538
# ...

# %%
#df.columns

#df[['Article keywords','Molecule keywords','Semiconductor']][0:5]

#df.iloc[1]

# print(df.iloc[2,1])

# for index, row in df.iterrows():
#      print(index, row['Semiconductor'])

df.loc[df['Semiconductor'] == "TiO2"]
# Out:
#         VOC     JSC     FF    PCE  \
# 258   601.0   2.070  0.802  1.000
# 259   494.0  13.670  0.726  4.900
# 260   714.0  13.200  0.768  7.300
# 261   693.0  13.260  0.741  6.800
# 262   640.0  14.230  0.719  6.600
# 263   756.0  11.850  0.720  6.400
# 264   709.0  11.600  0.706  5.800
# 265   664.0  12.350  0.697  5.700
# 311   716.0  12.080  0.680  5.870
# 337   755.0  11.680  0.600  5.250
# 415   758.0   9.010  0.710  4.870
# 416   726.0  11.730  0.670  5.700
# 417   740.0   9.690  0.590  4.210
# 630   760.0   3.070  0.740  1.540
# 631   710.0   5.040  0.720  2.540
# 632   770.0   7.200  0.680  3.230
# 633   770.0   1.712  0.641  0.695
# 665   555.0   2.186  0.626  0.819
# 670   680.0   4.390  0.710  2.150
# 672   670.0   4.180  0.740  2.090
# 724   650.0   3.300  0.670  1.440
# 725   750.0   8.590  0.710  4.570
# 726   740.0   4.700  0.730  2.520
# 727   760.0   8.470  0.700  4.540
# 728   720.0   3.690  0.700  1.870
# 3069  360.0   0.340  0.462  0.060
# ...

# %%
#df['Total'] = df['VOC'] + df['JSC'] + df['FF'] 

#df = df.drop(columns=['Total'])

#df['Total'] = df.iloc[:, 0:3].sum(axis=1)

df.head(5)
# Out:
#      VOC    JSC    FF   PCE  \
# 0  687.0  10.79  0.70  5.19
# 1  790.0   6.90  0.47  2.60
# 2  835.0   7.70  0.49  3.10
# 3  800.0   6.40  0.43  2.20
# 4  651.0  10.30  0.75  5.00
#
#                                          Electrolyte Active area Co-adsorbent  \
# 0  0.6 M 1-methyl-3-propylimidazolium iodide (PMI...           -            -
# 1  0.17 M Spiro-MeOTAD, 0.11 mM tert-butylpyridin...       0.158            -
# 2  0.17 M Spiro-MeOTAD, 0.11 mM tert-butylpyridin...       0.158            -
# 3  0.17 M Spiro-MeOTAD, 0.11 mM tert-butylpyridin...       0.158            -
# 4  1,3-dimethylimidazolium iodide, 1-ethyl-3methy...       0.158            -
#
#   Co-sensitizer                                   Semiconductor Dye loading  \
# 0             -                      TiO2 (20 nm particle size)           -
# 1             -  TiO2 film (8 uM thick + 5 uM scattering layer)           -
# 2             -  TiO2 film (8 uM thick + 5 uM scattering layer)           -
# ...

# %%
687.0 + 10.79 + 0.70
# Out:
# 698.49

# %%
cols = list(df.columns)
print(len(cols))

dfSwitch = df[cols[4:]+cols[0:4]]
dfSwitch
# Out:
# 30
#                                             Electrolyte Active area  \
# 0     0.6 M 1-methyl-3-propylimidazolium iodide (PMI...           -
# 1     0.17 M Spiro-MeOTAD, 0.11 mM tert-butylpyridin...       0.158
# 2     0.17 M Spiro-MeOTAD, 0.11 mM tert-butylpyridin...       0.158
# 3     0.17 M Spiro-MeOTAD, 0.11 mM tert-butylpyridin...       0.158
# 4     1,3-dimethylimidazolium iodide, 1-ethyl-3methy...       0.158
# 5     1,3-dimethylimidazolium iodide, 1-ethyl-3methy...       0.158
# 6     1,3-dimethylimidazolium iodide, 1-ethyl-3methy...       0.158
# 7     1.0 M 1,3-dimethylimidazolium iodide, 0.03 M I...       0.158
# 8     1.0 M 1,3-dimethylimidazolium iodide, 0.03 M I...       0.158
# 9     1.0 M 1,3-dimethylimidazolium iodide, 0.03 M I...       0.158
# 10                         OPV-AN-I  (iodide-triiodide)        0.16
# 11                         OPV-AN-I  (iodide-triiodide)        0.16
# 12                         OPV-AN-I  (iodide-triiodide)        0.16
# ...

# %%
dfTiONiO = dfSwitch.loc[df['Semiconductor'].str.contains('TiO2|NiO', regex=True)]

dfTiONiO.sort_values('PCE', ascending=False)

# dfFiltered = dfFiltered.reset_index()

# dfFiltered
# Out:
#                                             Electrolyte Active area  \
# 3761            cobalt tris(bipyridine) in acetonitrile           -
# 3634  0.165 M [Co(bpy)3](B(CN)4)2, 0.045 M [Co(bpy)3...        0.36
# 3633  0.165 M [Co(bpy)3](B(CN)4)2, 0.045 M [Co(bpy)3...        0.36
# 3760            cobalt tris(bipyridine) in acetonitrile           -
# 3645  0.165 M [Co(bpy)3](B(CN)4)2, 0.045 M [Co(bpy)3...        0.36
# 866   0.25 M [Co(Cl-phen)3]2+(PF6-)2, 0.035 M [Co(Cl...       0.102
# 3640  0.165 M [Co(bpy)3](B(CN)4)2, 0.045 M [Co(bpy)3...        0.36
# 3642  0.165 M [Co(bpy)3](B(CN)4)2, 0.045 M [Co(bpy)3...        0.36
# 3318            cobalt tris(bipyridine) in acetonitrile           -
# 1206  0.25 M tris(1,10-phenanthroline)cobalt(II) di[...        0.16
# 3635  0.165 M [Co(bpy)3](B(CN)4)2, 0.045 M [Co(bpy)3...        0.36
# 2688  0.22 M [CoII(bpy)3](B(CN)4)2, 0.05 M [CoIII(bp...       0.141
# 3641  0.165 M [Co(bpy)3](B(CN)4)2, 0.045 M [Co(bpy)3...        0.36
# ...

# %%
dfTiONiO['ClassType'] = ""

dfTiONiO.loc[dfTiONiO['PCE'] >= 11, 'ClassType'] = 'Good'
dfTiONiO.loc[(dfTiONiO['PCE']<11) & (dfTiONiO['PCE']>=5), 'ClassType'] = 'Okay'
dfTiONiO.loc[dfTiONiO['PCE']<5, 'ClassType'] = 'Poor'

dfTiONiO.sort_values('PCE', ascending=False)
# Out:
# C:\Users\Paul\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Paul\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#                                             Electrolyte Active area  \
# 3761            cobalt tris(bipyridine) in acetonitrile           -
# 3634  0.165 M [Co(bpy)3](B(CN)4)2, 0.045 M [Co(bpy)3...        0.36
# ...

# %%
df.groupby(['Molecule keywords', 'Semiconductor']).mean().sort_values('PCE', ascending=False)
# Out:
#                                                                                              VOC  \
# Molecule keywords                 Semiconductor
# perylene                          TiO2 film (5.2 um + 5 um scattering layer)          926.500000
# porphyrin                         TiO2 film (5 um transparent + 5 um scattering l...  855.000000
# triphenylamine                    TiO2 film + 3D photonic crystal layer               811.000000
#                                   TiO2 film (4 um thick + 3.5 um scattering layer)    824.750000
# N749 black dye, Ruthenium         TiO2 film 40 um thick                               689.666667
#                                   TiO2 film 45 um thick                               700.000000
# perylene                          TiO2 film (4.5 um + 5 um scattering layer)          885.000000
# porphyrin                         TiO2 film (4.2 uM thick + 5 uM scattering layer)    917.000000
# ...
